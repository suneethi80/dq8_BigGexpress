# %%
import pandas as pd
import seaborn as sns
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
faults=pd.read_csv('data/J1939Faults.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
faults.head()
# Out:
#    RecordID  ESS_Id           EventTimeStamp  \
# 0         1  990349  2015-02-21 10:47:13.000
# 1         2  990360  2015-02-21 11:34:34.000
# 2         3  990364  2015-02-21 11:35:31.000
# 3         4  990370  2015-02-21 11:35:33.000
# 4         5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription  actionDescription  \
# 0  Low (Severity Low) Engine Coolant Level                NaN
# 1                                      NaN                NaN
# 2      Incorrect Data Steering Wheel Angle                NaN
# 3      Incorrect Data Steering Wheel Angle                NaN
# 4                                      NaN                NaN
#
#                      ecuSoftwareVersion ecuSerialNumber              ecuModel  \
# 0                               unknown         unknown               unknown
# 1                               unknown         unknown               unknown
# 2                               unknown         unknown               unknown
# 3                               unknown         unknown               unknown
# 4  22281684P01*22357957P01*22362082P01*        13063430  0USA13_13_0415_2238A
#
#    ecuMake  ecuSource   spn  fmi  active  activeTransitionCount  faultValue  \
# 0  unknown          0   111   17    True                      2         NaN
# 1  unknown         11   629   12    True                    127         NaN
# 2  unknown         11  1807    2   False                    127         NaN
# 3  unknown         11  1807    2    True                    127         NaN
# 4    VOLVO          0  4364   17   False                      2         NaN
#
#   EquipmentID  MCTNumber   Latitude  Longitude        LocationTimeStamp
# 0        1439  105354361  38.857638 -84.626851  2015-02-21 11:34:25.000
# 1        1439  105354361  38.857638 -84.626851  2015-02-21 11:35:10.000
# 2        1369  105336226  41.421250 -87.767361  2015-02-21 11:35:26.000
# 3        1369  105336226  41.421018 -87.767361  2015-02-21 11:36:08.000
# 4        1674  105427130  38.416481 -89.442638  2015-02-21 11:39:37.000

# %%
faults.shape
# Out:
# (1187335, 20)

# %%
# vdod=vehicle diagnostic onboard data
vdod=pd.read_csv('data/VehicleDiagnosticOnboardData.csv')

# %%
vdod.head()
# Out:
#    Id                  Name     Value  FaultId
# 0   1             IgnStatus     False        1
# 1   2     EngineOilPressure         0        1
# 2   3  EngineOilTemperature  96.74375        1
# 3   4    TurboBoostPressure         0        1
# 4   5            EngineLoad        11        1

# %%
vdod.shape
# Out:
# (12821626, 4)

# %%
#vdod=vdod.rename(columns={'Name':'fault_nam})

# %%
vdod.Name.value_counts()
# Out:
# LampStatus                   1187335
# IgnStatus                     608454
# EngineRpm                     586921
# IntakeManifoldTemperature     586291
# EngineOilPressure             586244
# EngineCoolantTemperature      586071
# BarometricPressure            585976
# DistanceLtd                   585819
# EngineLoad                    585621
# FuelRate                      585237
# FuelLtd                       585195
# Speed                         583916
# EngineOilTemperature          583912
# TurboBoostPressure            583351
# EngineTimeLtd                 581366
# CruiseControlSetSpeed         576458
# CruiseControlActive           574916
# AcceleratorPedal              531889
# FuelLevel                     502795
# Throttle                      420503
# ParkingBrake                  399972
# FuelTemperature               299110
# SwitchedBatteryVoltage        114059
# ServiceDistance                  215
# Name: Name, dtype: int64

# %%
# Drop id columns and Pivot the vehicle diagnostics data
vdod_p=vdod.drop(columns='Id', axis=1)
vdod_p=vdod_p.pivot(index='FaultId', columns='Name', values='Value').reset_index()

# %%
vdod_p.columns.name = " "

# %%
vdod_p.head()
# Out:
#    FaultId AcceleratorPedal BarometricPressure CruiseControlActive  \
# 0        1                0              14.21               False
# 1        2              NaN                NaN                 NaN
# 2        3              NaN                NaN                 NaN
# 3        4              NaN                NaN                 NaN
# 4        5              NaN                NaN                 NaN
#
#   CruiseControlSetSpeed DistanceLtd EngineCoolantTemperature EngineLoad  \
# 0              66.48672    423178.7                    100.4         11
# 1                   NaN         NaN                      NaN        NaN
# 2                   NaN         NaN                      NaN        NaN
# 3                   NaN         NaN                      NaN        NaN
# 4                   NaN         NaN                      NaN        NaN
#
#   EngineOilPressure EngineOilTemperature EngineRpm EngineTimeLtd FuelLevel  \
# 0                 0             96.74375         0        1632.2      43.2
# 1               NaN                  NaN       NaN           NaN       NaN
# 2               NaN                  NaN       NaN           NaN       NaN
# 3               NaN                  NaN       NaN           NaN       NaN
# 4               NaN                  NaN       NaN           NaN       NaN
#
#            FuelLtd FuelRate FuelTemperature IgnStatus  \
# 0  12300.907429328        0             NaN     False
# 1              NaN      NaN             NaN      True
# 2              NaN      NaN             NaN       NaN
# 3              NaN      NaN             NaN      True
# 4              NaN      NaN             NaN       NaN
#
#   IntakeManifoldTemperature LampStatus ParkingBrake ServiceDistance Speed  \
# 0                      78.8       1023         True             NaN     0
# 1                       NaN       1279          NaN             NaN   NaN
# 2                       NaN       1279          NaN             NaN   NaN
# 3                       NaN       1279          NaN             NaN   NaN
# 4                       NaN      16639          NaN             NaN   NaN
#
#   SwitchedBatteryVoltage Throttle TurboBoostPressure
# 0                3276.75      NaN                  0
# 1                    NaN      NaN                NaN
# 2                    NaN      NaN                NaN
# 3                    NaN      NaN                NaN
# 4                    NaN      NaN                NaN

# %%
vdod_p.shape
# Out:
# (1187335, 25)

# %%
faults_vdod=pd.merge(faults, vdod_p, how='inner', left_on='RecordID', right_on='FaultId')

# %%
faults_vdod.head()
# Out:
#    RecordID  ESS_Id           EventTimeStamp  \
# 0         1  990349  2015-02-21 10:47:13.000
# 1         2  990360  2015-02-21 11:34:34.000
# 2         3  990364  2015-02-21 11:35:31.000
# 3         4  990370  2015-02-21 11:35:33.000
# 4         5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription  actionDescription  \
# 0  Low (Severity Low) Engine Coolant Level                NaN
# 1                                      NaN                NaN
# 2      Incorrect Data Steering Wheel Angle                NaN
# 3      Incorrect Data Steering Wheel Angle                NaN
# 4                                      NaN                NaN
#
#                      ecuSoftwareVersion ecuSerialNumber              ecuModel  \
# 0                               unknown         unknown               unknown
# 1                               unknown         unknown               unknown
# 2                               unknown         unknown               unknown
# 3                               unknown         unknown               unknown
# 4  22281684P01*22357957P01*22362082P01*        13063430  0USA13_13_0415_2238A
#
#    ecuMake  ecuSource   spn  fmi  active  activeTransitionCount  faultValue  \
# 0  unknown          0   111   17    True                      2         NaN
# 1  unknown         11   629   12    True                    127         NaN
# 2  unknown         11  1807    2   False                    127         NaN
# 3  unknown         11  1807    2    True                    127         NaN
# 4    VOLVO          0  4364   17   False                      2         NaN
#
#   EquipmentID  MCTNumber   Latitude  Longitude        LocationTimeStamp  \
# 0        1439  105354361  38.857638 -84.626851  2015-02-21 11:34:25.000
# 1        1439  105354361  38.857638 -84.626851  2015-02-21 11:35:10.000
# 2        1369  105336226  41.421250 -87.767361  2015-02-21 11:35:26.000
# 3        1369  105336226  41.421018 -87.767361  2015-02-21 11:36:08.000
# 4        1674  105427130  38.416481 -89.442638  2015-02-21 11:39:37.000
#
#    FaultId AcceleratorPedal BarometricPressure CruiseControlActive  \
# 0        1                0              14.21               False
# 1        2              NaN                NaN                 NaN
# 2        3              NaN                NaN                 NaN
# 3        4              NaN                NaN                 NaN
# 4        5              NaN                NaN                 NaN
#
#   CruiseControlSetSpeed DistanceLtd EngineCoolantTemperature EngineLoad  \
# 0              66.48672    423178.7                    100.4         11
# 1                   NaN         NaN                      NaN        NaN
# 2                   NaN         NaN                      NaN        NaN
# 3                   NaN         NaN                      NaN        NaN
# 4                   NaN         NaN                      NaN        NaN
#
#   EngineOilPressure EngineOilTemperature EngineRpm EngineTimeLtd FuelLevel  \
# 0                 0             96.74375         0        1632.2      43.2
# 1               NaN                  NaN       NaN           NaN       NaN
# 2               NaN                  NaN       NaN           NaN       NaN
# 3               NaN                  NaN       NaN           NaN       NaN
# 4               NaN                  NaN       NaN           NaN       NaN
#
#            FuelLtd FuelRate FuelTemperature IgnStatus  \
# 0  12300.907429328        0             NaN     False
# 1              NaN      NaN             NaN      True
# 2              NaN      NaN             NaN       NaN
# 3              NaN      NaN             NaN      True
# 4              NaN      NaN             NaN       NaN
#
#   IntakeManifoldTemperature LampStatus ParkingBrake ServiceDistance Speed  \
# 0                      78.8       1023         True             NaN     0
# 1                       NaN       1279          NaN             NaN   NaN
# 2                       NaN       1279          NaN             NaN   NaN
# 3                       NaN       1279          NaN             NaN   NaN
# 4                       NaN      16639          NaN             NaN   NaN
#
#   SwitchedBatteryVoltage Throttle TurboBoostPressure
# 0                3276.75      NaN                  0
# 1                    NaN      NaN                NaN
# 2                    NaN      NaN                NaN
# 3                    NaN      NaN                NaN
# 4                    NaN      NaN                NaN

# %%
faults_vdod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1187335 entries, 0 to 1187334
# Data columns (total 45 columns):
# RecordID                     1187335 non-null int64
# ESS_Id                       1187335 non-null int64
# EventTimeStamp               1187335 non-null object
# eventDescription             1126490 non-null object
# actionDescription            0 non-null float64
# ecuSoftwareVersion           891285 non-null object
# ecuSerialNumber              844318 non-null object
# ecuModel                     1122577 non-null object
# ecuMake                      1122577 non-null object
# ecuSource                    1187335 non-null int64
# spn                          1187335 non-null int64
# fmi                          1187335 non-null int64
# active                       1187335 non-null bool
# activeTransitionCount        1187335 non-null int64
# faultValue                   0 non-null float64
# EquipmentID                  1187335 non-null object
# MCTNumber                    1187335 non-null int64
# Latitude                     1187335 non-null float64
# Longitude                    1187335 non-null float64
# LocationTimeStamp            1187335 non-null object
# FaultId                      1187335 non-null int64
# AcceleratorPedal             531889 non-null object
# BarometricPressure           585976 non-null object
# CruiseControlActive          574916 non-null object
# CruiseControlSetSpeed        576458 non-null object
# DistanceLtd                  585819 non-null object
# EngineCoolantTemperature     586071 non-null object
# EngineLoad                   585621 non-null object
# EngineOilPressure            586244 non-null object
# EngineOilTemperature         583912 non-null object
# EngineRpm                    586921 non-null object
# EngineTimeLtd                581366 non-null object
# FuelLevel                    502795 non-null object
# FuelLtd                      585195 non-null object
# FuelRate                     585237 non-null object
# FuelTemperature              299110 non-null object
# IgnStatus                    608454 non-null object
# IntakeManifoldTemperature    586291 non-null object
# LampStatus                   1187335 non-null object
# ParkingBrake                 399972 non-null object
# ServiceDistance              215 non-null object
# Speed                        583916 non-null object
# SwitchedBatteryVoltage       114059 non-null object
# Throttle                     420503 non-null object
# TurboBoostPressure           583351 non-null object
# dtypes: bool(1), float64(4), int64(8), object(32)
# memory usage: 408.8+ MB

# %%
#mask = np.column_stack([faults_vdod[col].str.contains(r"\,", na=False) for col in faults_vdod])
#faults_vdod.loc[mask.any(axis=1)]

# %%
#round the location of the 3 locations to be removed (they were service centers)
#193 Aldi Blvd, Mt Juliet, TN: 36.0666667, -86.4347222
#137 Eady Road – Bell Buckle, TN: 35.5883333, -86.4438888
#5754 Fish Hatchery Road – Russellville, TN: 36.1950, -83.174722
faults_vdod['lat_r']=faults_vdod['Latitude'].round(decimals = 1)
faults_vdod['lon_r']=faults_vdod['Longitude'].round(decimals=1)
faults_vdod=faults_vdod.drop([])

# %%
faults_vdod.head()
# Out:
#    RecordID  ESS_Id           EventTimeStamp  \
# 0         1  990349  2015-02-21 10:47:13.000
# 1         2  990360  2015-02-21 11:34:34.000
# 2         3  990364  2015-02-21 11:35:31.000
# 3         4  990370  2015-02-21 11:35:33.000
# 4         5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription  actionDescription  \
# 0  Low (Severity Low) Engine Coolant Level                NaN
# 1                                      NaN                NaN
# 2      Incorrect Data Steering Wheel Angle                NaN
# 3      Incorrect Data Steering Wheel Angle                NaN
# 4                                      NaN                NaN
#
#                      ecuSoftwareVersion ecuSerialNumber              ecuModel  \
# 0                               unknown         unknown               unknown
# 1                               unknown         unknown               unknown
# 2                               unknown         unknown               unknown
# 3                               unknown         unknown               unknown
# 4  22281684P01*22357957P01*22362082P01*        13063430  0USA13_13_0415_2238A
#
#    ecuMake  ecuSource   spn  fmi  active  activeTransitionCount  faultValue  \
# 0  unknown          0   111   17    True                      2         NaN
# 1  unknown         11   629   12    True                    127         NaN
# 2  unknown         11  1807    2   False                    127         NaN
# 3  unknown         11  1807    2    True                    127         NaN
# 4    VOLVO          0  4364   17   False                      2         NaN
#
#   EquipmentID  MCTNumber   Latitude  Longitude        LocationTimeStamp  \
# 0        1439  105354361  38.857638 -84.626851  2015-02-21 11:34:25.000
# 1        1439  105354361  38.857638 -84.626851  2015-02-21 11:35:10.000
# 2        1369  105336226  41.421250 -87.767361  2015-02-21 11:35:26.000
# 3        1369  105336226  41.421018 -87.767361  2015-02-21 11:36:08.000
# 4        1674  105427130  38.416481 -89.442638  2015-02-21 11:39:37.000
#
#    FaultId AcceleratorPedal BarometricPressure CruiseControlActive  \
# 0        1                0              14.21               False
# 1        2              NaN                NaN                 NaN
# 2        3              NaN                NaN                 NaN
# 3        4              NaN                NaN                 NaN
# 4        5              NaN                NaN                 NaN
#
#   CruiseControlSetSpeed DistanceLtd EngineCoolantTemperature EngineLoad  \
# 0              66.48672    423178.7                    100.4         11
# 1                   NaN         NaN                      NaN        NaN
# 2                   NaN         NaN                      NaN        NaN
# 3                   NaN         NaN                      NaN        NaN
# 4                   NaN         NaN                      NaN        NaN
#
#   EngineOilPressure EngineOilTemperature EngineRpm EngineTimeLtd FuelLevel  \
# 0                 0             96.74375         0        1632.2      43.2
# 1               NaN                  NaN       NaN           NaN       NaN
# 2               NaN                  NaN       NaN           NaN       NaN
# 3               NaN                  NaN       NaN           NaN       NaN
# 4               NaN                  NaN       NaN           NaN       NaN
#
#            FuelLtd FuelRate FuelTemperature IgnStatus  \
# 0  12300.907429328        0             NaN     False
# 1              NaN      NaN             NaN      True
# 2              NaN      NaN             NaN       NaN
# 3              NaN      NaN             NaN      True
# 4              NaN      NaN             NaN       NaN
#
#   IntakeManifoldTemperature LampStatus ParkingBrake ServiceDistance Speed  \
# 0                      78.8       1023         True             NaN     0
# 1                       NaN       1279          NaN             NaN   NaN
# 2                       NaN       1279          NaN             NaN   NaN
# 3                       NaN       1279          NaN             NaN   NaN
# 4                       NaN      16639          NaN             NaN   NaN
#
#   SwitchedBatteryVoltage Throttle TurboBoostPressure  lat_r  lon_r
# 0                3276.75      NaN                  0   38.9  -84.6
# 1                    NaN      NaN                NaN   38.9  -84.6
# 2                    NaN      NaN                NaN   41.4  -87.8
# 3                    NaN      NaN                NaN   41.4  -87.8
# 4                    NaN      NaN                NaN   38.4  -89.4

# %%
faults_vdod.drop(columns=['actionDescription', 'faultValue')
